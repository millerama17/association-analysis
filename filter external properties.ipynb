# %%
import pandas as pd

# %%
df_ep = pd.read_csv("external_prop_2023.csv")

# %%
df_gp_example = pd.read_excel("gap_properties_cs.xlsx")

# %%
df_gp_example
# Out:
#    antecedents                               consequents  antecedent support  \
# 0         rich                          NDL Authority ID                 0.5
# 1         rich                                   FAST ID                 0.5
# 2         rich                     CiNii Books author ID                 0.5
# 3         rich                                      ISNI                 0.5
# 4         rich                                  NUKAT ID                 0.5
# 5         rich                                  IdRef ID                 0.5
# 6         rich               Canadiana Name Authority ID                 0.5
# 7         rich       Bibliothèque nationale de France ID                 0.5
# 8         rich                 SHARE Catalogue author ID                 0.5
# 9         rich                        RERO ID (obsolete)                 0.5
# 10        rich                                 PLWABN ID                 0.5
# ...

# %%
property_labels_in_df_ep = df_ep['Property Label'].tolist()
filtered_dataframe = df_gp_example[~df_gp_example['consequents'].isin(property_labels_in_df_ep)]

# %%
filtered_dataframe
# Out:
#    antecedents                               consequents  antecedent support  \
# 0         rich                          NDL Authority ID                 0.5
# 1         rich                                   FAST ID                 0.5
# 2         rich                     CiNii Books author ID                 0.5
# 3         rich                                      ISNI                 0.5
# 4         rich                                  NUKAT ID                 0.5
# 5         rich                                  IdRef ID                 0.5
# 6         rich               Canadiana Name Authority ID                 0.5
# 7         rich       Bibliothèque nationale de France ID                 0.5
# 8         rich                 SHARE Catalogue author ID                 0.5
# 9         rich                        RERO ID (obsolete)                 0.5
# 10        rich                                 PLWABN ID                 0.5
# ...

# %%
filtered_dataframe.to_excel("gap_properties_cs_without_external_property.xlsx", index=False)
